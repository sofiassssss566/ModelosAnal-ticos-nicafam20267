# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiassssss566/ModelosAnal-ticos-nicafam20267/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ACTIVIDAD 1 EJERCICIOS
#
#
# DOCENTE:NICOLAS MOJICA
#
#
# ESTUDIANTE:YINET SANCHEZ

# %% [markdown]
# #OPERACIONES MATEMATICAS

# %%
#EJERCICIO1
print("Declara dos variables a y b con los valores 10 y 3, respectivamente.")
# Out:
# Declara dos variables a y b con los valores 10 y 3, respectivamente.

# %%
a=10
b=3
print(a)
print(b)
# Out:
# 10
# 3

# %%
#2.Calcula la suma de a y b y asígnala a una variable suma.

# %%
print(a+b)
suma=a+b
print(suma)
# Out:
# 13
# 13

# %%
#3.Calcula la resta de a y b y asígnala a una variable resta.

# %%
print(a-b)
var="resta"
# Out:
# 7
# resta

# %%
#Calcula la multiplicación de a y b y asígnala a una variable multiplicacion.

# %%
print(a*b)
var="multiplicaion"
print(var)
# Out:
# 30
# multiplicaion

# %%
#Calcula la división de a entre b y asígnala a una variable division.

# %%
print(a/b)
var="division"
print(var)
# Out:
# 3.3333333333333335
# division

# %%
#Calcula el módulo de a y b y asígnalo a una variable modulo.

# %%
print(a%b)
var="modulo"
print(var)
# Out:
# 1
# modulo

# %%
#Calcula la potencia de a elevado a b y asígnala a una variable potencia.

# %%
print(a**b)
var="potencia"
print(var)
# Out:
# 1000
# potencia

# %%
#Calcula la división entera de a entre b y asígnala a una variable division_entera

# %%
print(a//b)
var="division_entera"
print(var)
# Out:
# 3
# division_entera

# %% [markdown]
# ## VALORES DE CADENA

# %%
#Declara una cadena llamada saludo con el valor "Hola, mundo!".

# %%
saludo="hola, mundo!"

# %%
#Accede y muestra el primer carácter de la cadena saludo.

# %%
print(saludo[0])
# Out:
# h

# %%
#Accede y muestra los últimos 5 caracteres de la cadena saludo.

# %%
print(saludo[6:11])
# Out:
# mundo

# %%
#Concatenar la cadena saludo con otra cadena ", ¿cómo estás?" y asígnala a una nueva variable saludo_completo.

# %%
saludo2="¿cómo estás?"
print(saludo+", "+saludo2)
saludo_completo=saludo+saludo2
# Out:
# hola, mundo, ¿cómo estás?

# %%
#Convierte la cadena saludo_completo a mayúsculas y asígnala a una variable saludo_mayusculas.

# %%
print(saludo_completo.upper())
# Out:
# HOLA, MUNDO¿CÓMO ESTÁS?

# %%
#Reemplaza la palabra "mundo" en saludo_completo por "Python" y asígnala a una variable saludo_reemplazo.

# %%
saludo="hola, python "
saludo_reemplazo=saludo+saludo2
print(saludo_reemplazo)
# Out:
# hola, python ¿cómo estás?
