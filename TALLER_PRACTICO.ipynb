# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiassssss566/ModelosAnal-ticos-nicafam20267/blob/main/TALLER_PRACTICO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Menú de mi Perfil con Diccionarios en Python
#
# MODELOS ANALITICOS
#
# UNICAFAM
#
# DOCENTE:NICOLAS MOJICA
#
# ESTUDIANTE:YINET SANCHEZ

# %%
# Taller: Menú de mi Perfil con Diccionarios en Python
